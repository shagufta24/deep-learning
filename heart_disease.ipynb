# %%
import pandas as pd
import numpy as np
from ann_funcs import *

# %%
df = pd.read_csv("framingham_heart_disease.csv")
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df=(df-df.min())/(df.max()-df.min())
df.head()
# Out:
#    male       age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0   1.0  0.184211   1.000000            0.0    0.000000     0.0
# 1   0.0  0.368421   0.333333            0.0    0.000000     0.0
# 2   1.0  0.421053   0.000000            1.0    0.285714     0.0
# 3   0.0  0.763158   0.666667            1.0    0.428571     0.0
# 4   0.0  0.368421   0.666667            1.0    0.328571     0.0
#
#    prevalentStroke  prevalentHyp  diabetes   totChol     sysBP     diaBP  \
# 0              0.0           0.0       0.0  0.149406  0.106383  0.232804
# 1              0.0           0.0       0.0  0.242784  0.177305  0.349206
# 2              0.0           0.0       0.0  0.234295  0.208038  0.338624
# 3              0.0           1.0       0.0  0.200340  0.314421  0.497354
# 4              0.0           0.0       0.0  0.302207  0.219858  0.380952
#
#         BMI  heartRate   glucose  TenYearCHD
# 0  0.277024   0.363636  0.104520         0.0
# 1  0.319680   0.515152  0.101695         0.0
# ...

# %%
df = df.dropna().reset_index(drop=True)

# %%
x = np.transpose(np.array(df.iloc[:, :-1]))
y = np.transpose(np.array(df.iloc[:, -1]))
y = y.reshape(1, y.shape[0])

train_x = x
train_y = y

# %%
print("train_x shape:", train_x.shape)
print("train_y shape:", train_y.shape)
# print("test_x shape:", test_x.shape)
# print("test_y shape:", test_y.shape)
# Out:
# train_x shape: (15, 3656)
# train_y shape: (1, 3656)

# %%
print("No. of samples: ", x.shape[1])
print("No. of features: ", x.shape[0])
# Out:
# No. of samples:  3656
# No. of features:  15

# %%
layers_dims = [15, 3, 3, 1]

# %%
parameters = L_layer_model(train_x, train_y, layers_dims, learning_rate = 0.05, num_iterations = 5000, print_cost = True, cost_func = "log", activation = "tanh", last_activation = "sigmoid", he_init = True)
# Out:
# Cost after iteration 0: 0.806309
# Cost after iteration 100: 0.431003
# Cost after iteration 200: 0.425499
# Cost after iteration 300: 0.421416
# Cost after iteration 400: 0.417308
# Cost after iteration 500: 0.413585
# Cost after iteration 600: 0.410478
# Cost after iteration 700: 0.407929
# Cost after iteration 800: 0.405806
# Cost after iteration 900: 0.403981
# Cost after iteration 1000: 0.402350
# Cost after iteration 1100: 0.400841
# Cost after iteration 1200: 0.399412
# Cost after iteration 1300: 0.398041
# Cost after iteration 1400: 0.396725
# Cost after iteration 1500: 0.395467
# Cost after iteration 1600: 0.394278
# Cost after iteration 1700: 0.393166
# Cost after iteration 1800: 0.392135
# Cost after iteration 1900: 0.391186
# Cost after iteration 2000: 0.390315
# Cost after iteration 2100: 0.389517
# Cost after iteration 2200: 0.388787
# Cost after iteration 2300: 0.388119
# Cost after iteration 2400: 0.387509
# Cost after iteration 2500: 0.386952
# ...

# %%
classes = predict_binary_classes(train_x, train_y, parameters, "tanh", "sigmoid")
# Out:
# Accuracy: 0.8476477024070024
